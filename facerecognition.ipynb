# %% [markdown]
# <a href="https://colab.research.google.com/github/rishithareddy02/rishithareddy02/blob/main/facerecognition.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install mtcnn
import cv2
import urllib.request
from mtcnn import MTCNN
import matplotlib.pyplot as plt
from google.colab import files
detector = MTCNN()
def recognize_faces(image):
    rgb_image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    faces = detector.detect_faces(rgb_image)
    for face in faces:
        x, y, width, height = face['box']
        cv2.rectangle(image, (x, y), (x+width, y+height), (0, 255, 0), 2)
    plt.imshow(rgb_image)
    plt.axis('off')
    plt.show()
    return len(faces)
def calculate_accuracy(image_path):
    image = cv2.imread(image_path)
    detected_faces = recognize_faces(image)
    accuracy = detected_faces / 1 * 100
    print(f"Number of detected faces: {detected_faces}")
    print(f"Accuracy: {accuracy:.2f}%")
uploaded = files.upload()
image_path = list(uploaded.keys())[0]
calculate_accuracy(image_path)
# Out:
# ...
#      <input type="file" id="files-3e784092-b39b-49f1-8ad2-5f09599e03b3" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3e784092-b39b-49f1-8ad2-5f09599e03b3">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...
